# %% [markdown]
# # Event-related Stock Price Analysis
# ### This code analyze the impact on stock market caused by various events during COVID era

# %% [markdown]
# ## Load stock price data

# %%
import pandas_datareader
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /var/folders/nv/1z2wmgld0b1bd9l3x_x6d7rh0000gn/T/ipykernel_41428/1561137876.py in <module>
# ----> 1 import pandas_datareader
#
# ModuleNotFoundError: No module named 'pandas_datareader'

# %%
import pandas_datareader as data
import datetime

# %%
start_date = datetime.datetime(1980,1,1)
end_date = datetime.datetime(2021,12,15)

# Kosdaq data
KQData = data.DataReader('^KQ11', 'yahoo', start_date, end_date)
print(KQData.head)
# Out:
# <bound method NDFrame.head of                    High          Low         Open        Close     Volume  \
# Date
# 2000-10-16   873.900024   851.299988   858.500000   867.099976   193900.0
# 2000-10-17   860.099976   791.099976   849.599976   804.000000   218200.0
# 2000-10-18   811.400024   758.200012   788.500000   802.599976   241000.0
# 2000-10-19   820.400024   786.900024   793.599976   798.400024   204500.0
# 2000-10-20   840.900024   822.500000   834.700012   826.200012   221900.0
# ...                 ...          ...          ...          ...        ...
# 2021-12-09  1022.869995  1009.289978  1009.289978  1022.869995  1061000.0
# 2021-12-10  1018.419983  1010.020020  1016.340027  1011.570007     1200.0
# 2021-12-13  1014.900024  1005.960022  1014.270020  1005.960022     1300.0
# 2021-12-14  1007.729980   996.849976  1001.109985  1002.809998     1100.0
# 2021-12-15  1007.440002   999.210022  1002.179993  1003.520020  1125300.0
#
#               Adj Close
# Date
# 2000-10-16   867.099976
# 2000-10-17   804.000000
# 2000-10-18   802.599976
# 2000-10-19   798.400024
# 2000-10-20   826.200012
# ...                 ...
# 2021-12-09  1022.869995
# 2021-12-10  1011.570007
# 2021-12-13  1005.960022
# 2021-12-14  1002.809998
# 2021-12-15  1003.520020
#
# [5228 rows x 6 columns]>

# %%
KQData['Close'].plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
import FinanceDataReader as fdr
df_ss = fdr.DataReader('005930', '2020')

# %%
df_ss
# Out:
#              Open   High    Low  Close    Volume    Change
# Date
# 2020-01-02  55500  56000  55000  55200  12993228 -0.010753
# 2020-01-03  56000  56600  54900  55500  15422255  0.005435
# 2020-01-06  54900  55600  54600  55500  10278951  0.000000
# 2020-01-07  55700  56400  55600  55800  10009778  0.005405
# 2020-01-08  56200  57400  55900  56800  23501171  0.017921
# ...           ...    ...    ...    ...       ...       ...
# 2021-12-14  76500  77200  76200  77000  10976660  0.002604
# 2021-12-15  76400  77600  76300  77600   9584939  0.007792
# 2021-12-16  78500  78500  77400  77800  11996128  0.002577
# 2021-12-17  76800  78000  76800  78000  13108479  0.002571
# 2021-12-20  77600  77800  76800  77100  11170845 -0.011538
#
# [488 rows x 6 columns]

# %%
df_etf = fdr.StockListing('KONEX')

# %%
df_etf
# Out:
#       Symbol Market      Name                                 Sector  \
# 95    278990  KONEX       EMB      전동기, 발전기 및 전기 변환 · 공급 · 제어 장치 제조업
# 1189  112190  KONEX      KC산업               시멘트, 석회, 플라스터 및 그 제품 제조업
# 1964  183410  KONEX     골프존데카  측정, 시험, 항해, 제어 및 기타 정밀기기 제조업; 광학기기 제외
# 1965  076340  KONEX      관악산업                  기반조성 및 시설물 축조관련 전문공사업
# 1990  243870  KONEX        굿센                컴퓨터 프로그래밍, 시스템 통합 및 관리업
# ...      ...    ...       ...                                    ...
# 5405  150440  KONEX       피노텍                         소프트웨어 개발 및 공급업
# 5416  242350  KONEX   피엔아이컴퍼니              영화, 비디오물, 방송프로그램 제작 및 배급업
# 6821  331660  KONEX  한국미라클피플사                            기타 화학제품 제조업
# 6917  107640  KONEX    한중엔시에스                          자동차 신품 부품 제조업
# 7050  212310  KONEX       휴벡셀                             의료용 기기 제조업
#
#                                                Industry ListingDate  \
# 95                                      태양광ESS,휴대폰 액세서리  2017-10-31
# 1189                                         철강보강콘크리트제품  2016-05-31
# 1964                                            골프거리측정기  2013-11-12
# 1965                                       수중공사, 준설공사 등  2015-05-18
# 1990                                      건설ERP, 공공클라우드  2016-10-31
# ...                                                 ...         ...
# 5405  인터넷전자등기시스템, 비대면금융거래플랫폼, 로보카운슬링 솔루션, 비대면실명확인 솔루...  2014-12-05
# 5416                        3D 애니메이션, 3D VR 시뮬레이터 및 콘텐츠  2016-12-22
# 6821                                     은나노스텝, 닥터오렌지 등  2019-10-28
# 6917  자동차 신품 부품제조업(배기시스템부품, Electroinc, 전기차 밧데리 모듈 부...  2013-12-10
# 7050                                         척추용 임플란트 등  2016-07-26
#
#      SettleMonth  Representative                     HomePage   Region
# 95           12월             홍지태  http://www.fineemtech.co.kr      경기도
# 1189         12월  이홍재, 박광노(각자대표)      http://www.kccond.co.kr      경기도
# 1964         12월             정주명      http://www.golfbuddy.kr      경기도
# 1965         12월             이규항     http://www.gwan-ak.co.kr    서울특별시
# 1990         12월               -       http://www.goodcen.com    서울특별시
# ...          ...             ...                          ...      ...
# 5405         12월             김우섭     http://www.finotek.co.kr    서울특별시
# 5416         12월             신재중    http://www.pnicompany.com  제주특별자치도
# 6821         12월             이호경        http://www.kmpc.co.kr      경기도
# 6917         12월             김환식         http://www.hjncs.com     경상북도
# 7050         12월  박정민, 허성규(각자대표)           http://huvexel.com      경기도
#
# [132 rows x 10 columns]
