# %% [markdown]
# # Trying to install XGBoost
# ## Use Scikit-learning Decision Tree and XGBoost

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import sklearn
import xgboost as xgb
from matplotlib import cm
import matplotlib.pyplot as plt
from sklearn.metrics import precision_score, recall_score, accuracy_score

# %%
from sklearn import tree
from sklearn.model_selection import train_test_split

# %% [markdown]
# # Load Diabetes Data
# ### Data Reference : IBM Coursera Deep-learning and Reinforcement learning Course week 2 Material.
# https://www.coursera.org/learn/deep-learning-reinforcement-learning/supplement/sABhA/keras-demo-activity

# %%
names = ["times_pregnant", "glucose_tolerance_test", "blood_pressure", "skin_thickness", "insulin", 
         "bmi", "pedigree_function", "age", "has_diabetes"]
diabetes_df = pd.read_csv('diabetes.csv', names=names, header=0)

# %%
diabetes_df
# Out:
#      times_pregnant  glucose_tolerance_test  blood_pressure  skin_thickness  \
# 0                 6                     148              72              35
# 1                 1                      85              66              29
# 2                 8                     183              64               0
# 3                 1                      89              66              23
# 4                 0                     137              40              35
# ..              ...                     ...             ...             ...
# 763              10                     101              76              48
# 764               2                     122              70              27
# 765               5                     121              72              23
# 766               1                     126              60               0
# 767               1                      93              70              31
#
#      insulin   bmi  pedigree_function  age  has_diabetes
# 0          0  33.6              0.627   50             1
# 1          0  26.6              0.351   31             0
# 2          0  23.3              0.672   32             1
# 3         94  28.1              0.167   21             0
# 4        168  43.1              2.288   33             1
# ..       ...   ...                ...  ...           ...
# 763      180  32.9              0.171   63             0
# 764        0  36.8              0.340   27             0
# 765      112  26.2              0.245   30             0
# 766        0  30.1              0.349   47             1
# 767        0  30.4              0.315   23             0
#
# [768 rows x 9 columns]

# %%
x = diabetes_df.iloc[:, :-1].values
y = diabetes_df.has_diabetes.values

# %% [markdown]
# ## Visualize the distributions of each variables.

# %%
clevels = np.linspace(0., 1., 8)
f, axs = plt.subplots(4,4, sharex=False,  gridspec_kw={"height_ratios":(.1,.4, 0.1, 0.4)})
plt.subplots_adjust(hspace=0.2)
f.set_figheight(15)
f.set_figwidth(15)
sns.set(style="ticks")
for i in range(8):
    xpos = np.random.normal(1, 0.08, x[:,i].shape)
    axs[int(np.floor(i/4)*2),int(np.mod(i,4))].boxplot(x[:,i],showfliers=False,vert=False)
    axs[int(np.floor(i/4)*2),int(np.mod(i,4))].scatter(x[:,i],xpos ,c=cm.rainbow([clevels[i]]), alpha=0.6 )
    axs[int(np.floor(i/4)*2),int(np.mod(i,4))].set(xticks=[])
    axs[int(np.floor(i/4)*2),int(np.mod(i,4))].spines.right.set_visible(False)
    axs[int(np.floor(i/4)*2),int(np.mod(i,4))].spines.top.set_visible(False)
    axs[int(np.floor(i/4)*2),int(np.mod(i,4))].spines.bottom.set_visible(False)
    sns.histplot(data=x[:,i], ax=axs[int(np.floor(i/4)*2)+1,int(np.mod(i,4))],kde=True)
    axs[int(np.floor(i/4)*2)+1,int(np.mod(i,4))].set_xlabel(names[i])
    axs[int(np.floor(i/4)*2)+1,int(np.mod(i,4))].spines.top.set_visible(False)
    axs[int(np.floor(i/4)*2)+1,int(np.mod(i,4))].spines.right.set_visible(False)

# %%
clevels = np.linspace(0., 1., 8)
f, axs = plt.subplots(4,4, sharex=False,  gridspec_kw={"height_ratios":(.1,.4, 0.1, 0.4)})
plt.subplots_adjust(hspace=0.2)
f.set_figheight(15)
f.set_figwidth(15)
sns.set(style="ticks")
for i in range(8):
    xpos = np.random.normal(1, 0.08, x[:,i].shape)
    axs[int(np.floor(i/4)*2),int(np.mod(i,4))].boxplot(x[:,i],showfliers=False,vert=False)
    axs[int(np.floor(i/4)*2),int(np.mod(i,4))].scatter(x[:,i],xpos ,c=cm.rainbow([clevels[i]]), alpha=0.6 )
    axs[int(np.floor(i/4)*2),int(np.mod(i,4))].set(xticks=[])
    axs[int(np.floor(i/4)*2),int(np.mod(i,4))].spines.right.set_visible(False)
    axs[int(np.floor(i/4)*2),int(np.mod(i,4))].spines.top.set_visible(False)
    axs[int(np.floor(i/4)*2),int(np.mod(i,4))].spines.bottom.set_visible(False)
    sns.histplot(data=x[:,i], ax=axs[int(np.floor(i/4)*2)+1,int(np.mod(i,4))],kde=True)
    axs[int(np.floor(i/4)*2)+1,int(np.mod(i,4))].set_xlabel(names[i])
    axs[int(np.floor(i/4)*2)+1,int(np.mod(i,4))].spines.top.set_visible(False)
    axs[int(np.floor(i/4)*2)+1,int(np.mod(i,4))].spines.right.set_visible(False)

# %% [markdown]
# # Split Datasets

# %%
xTrain, xTest,yTrain, yTest = train_test_split(x,y,test_size=0.2)

# %%
( xTrain.shape, xTest.shape, yTrain.shape,yTest.shape)
# Out:
# ((614, 8), (154, 8), (614,), (154,))

# %% [markdown]
# # Compare XGBoost and sklearn tree algoritm

# %% [markdown]
# ### Sklearn Decision Tree Algorithm.

# %%
dtClassifier =  tree.DecisionTreeClassifier()
dtClassifier.fit(xTrain, yTrain)
dtYPred = dtClassifier.predict(xTest)

accuracy = np.sum(yTest == dtYPred)/len(yTest)
accuracy
# Out:
# 0.7142857142857143

# %% [markdown]
# ### XGBoost

# %%
dataTrain = xgb.DMatrix(xTrain, label=yTrain)
dataTest = xgb.DMatrix(xTest, label=yTest)

param = {
    'eta': 0.3, 
    'max_depth': 6,
    'objective':'multi:softprob',
    'num_class':2}
steps = 40

model = xgb.train(param, dataTrain, steps)
xgYPred = model.predict(dataTest)
bestXGYPred = np.asarray([np.argmax(line) for line in xgYPred])
# Out:
# [23:50:37] WARNING: ..\src\learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.

# %%
np.sum(yTest == bestXGYPred)/len(yTest)
# Out:
# 0.7402597402597403

# %%
print("Decision Tree Precision = {}".format(precision_score(yTest, dtYPred, average='macro')))
print("XGBoost Precisioin = {}".format(precision_score(yTest, bestXGYPred, average='macro')))
print("Decision Tree Recall = {}".format(recall_score(yTest, dtYPred, average='macro')))
print("XGBoost Recall = {}".format(recall_score(yTest, bestXGYPred, average='macro')))
print("Decision Tree Accuracy = {}".format(accuracy_score(yTest, dtYPred)))
print("XGBoost Accuracy = {}".format(accuracy_score(yTest, bestXGYPred)))
# Out:
# Decision Tree Precision = 0.7151771336553945
# XGBoost Precisioin = 0.7461755233494365
# Decision Tree Recall = 0.6855902777777778
# XGBoost Recall = 0.7123263888888889
# Decision Tree Accuracy = 0.7142857142857143
# XGBoost Accuracy = 0.7402597402597403

# %% [markdown]
# # Visualize Pair-wise Decision Boundary
# ### Scikit Leearn Decision Tree Boundary

# %%
from sklearn.tree import plot_tree
import matplotlib.pyplot as plt

n_classes = 2
plot_colors = "yr"
plot_step = 0.1
plt.figure(figsize=(12, 16))
for pairidx, pair in enumerate([[1,2],[1,4],[1,5], [1,7],[2,4],[2,5],[2,7],[4,5],[4,7],[5,7]]):
    xTemp = x[:, pair]
    yTemp = y
    
    clf = tree.DecisionTreeClassifier().fit(xTemp, yTemp)
    plt.subplot(4,3, pairidx+1)
    
    x_min, x_max = xTemp[:,0].min()-1, xTemp[:,0].max()+1
    y_min, y_max = xTemp[:,1].min()-1, xTemp[:,1].max()+1
    xx, yy = np.meshgrid(
        np.arange(x_min, x_max, plot_step), np.arange(y_min, y_max, plot_step)
    )
    plt.tight_layout(h_pad=1, w_pad=1, pad=2.5)
    
    Z = clf.predict(np.c_[xx.ravel(), yy.ravel()])
    Z = Z.reshape(xx.shape)
    
    cs = plt.contourf(xx,yy,Z, cmap=plt.cm.autumn_r)
    plt.xlabel(names[pair[0]])
    plt.ylabel(names[pair[1]])
    for i, color in zip(range(n_classes), plot_colors):
        idx = np.where(yTemp==i)
        plt.scatter(
            xTemp[idx, 0],
            xTemp[idx, 1],
            c=color,
            cmap=plt.cm.autumn_r,
            edgecolor="black",
            s=15,
        )
plt.suptitle("Decision surface of a decision tree using paired features")
plt.legend(loc="lower right",borderpad=0, handletextpad=0)
plt.axis("tight")
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# (-1.0, 67.99999999999999, 20.0, 81.90000000000089)

# %% [markdown]
# ### XGBoost Decision Boundary

# %%
from sklearn.tree import plot_tree
import matplotlib.pyplot as plt

param = {
    'eta': 0.3, 
    'max_depth': 6,
    'objective':'multi:softprob',
    'num_class':2}
steps = 40

n_classes = 2
plot_colors = "yr"
plot_step = 0.1
plt.figure(figsize=(12, 16))
for pairidx, pair in enumerate([[1,2],[1,4],[1,5], [1,7],[2,4],[2,5],[2,7],[4,5],[4,7],[5,7]]):
    xTemp = x[:, pair]
    yTemp = y
    
    dataTemp = xgb.DMatrix(xTemp, label=yTemp)
    model = xgb.train(param, dataTemp, steps)

    plt.subplot(4,3, pairidx+1)
    
    x_min, x_max = xTemp[:,0].min()-1, xTemp[:,0].max()+1
    y_min, y_max = xTemp[:,1].min()-1, xTemp[:,1].max()+1
    xx, yy = np.meshgrid(
        np.arange(x_min, x_max, plot_step), np.arange(y_min, y_max, plot_step)
    )
    plt.tight_layout(h_pad=1, w_pad=1, pad=2.5)
    
    Z = model.predict(xgb.DMatrix(np.c_[xx.ravel(), yy.ravel()]))
    Z = np.asarray([np.argmax(line) for line in Z])
    Z = Z.reshape(xx.shape)
    
    cs = plt.contourf(xx,yy,Z, cmap=plt.cm.autumn_r)
    plt.xlabel(names[pair[0]])
    plt.ylabel(names[pair[1]])
    for i, color in zip(range(n_classes), plot_colors):
        idx = np.where(yTemp==i)
        plt.scatter(
            xTemp[idx, 0],
            xTemp[idx, 1],
            c=color,
            cmap=plt.cm.autumn_r,
            edgecolor="black",
            s=15,
        )
plt.suptitle("Decision surface of a decision tree using paired features")
plt.legend(loc="lower right",borderpad=0, handletextpad=0)
plt.axis("tight")
# Out:
# [23:57:56] WARNING: ..\src\learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [23:58:01] WARNING: ..\src\learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [23:58:35] WARNING: ..\src\learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [23:58:38] WARNING: ..\src\learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [23:58:40] WARNING: ..\src\learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [23:59:01] WARNING: ..\src\learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [23:59:03] WARNING: ..\src\learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [23:59:04] WARNING: ..\src\learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [23:59:16] WARNING: ..\src\learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [23:59:27] WARNING: ..\src\learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# (-1.0, 67.99999999999999, 20.0, 81.90000000000089)

# %% [markdown]
# # Visualization of Scikit-learning Decision Tree Structure

# %%
# import graphviz
from sklearn.tree import export_text
from sklearn.tree import export_graphviz
#dot_data = tree.export_graphviz(dtClassifier, out_file=None)
#graph = graphviz.Source(dot_data)
##graph.render("Diabetes")
print(export_text(dtClassifier, feature_names=names[0:8]))
# Out:
# |--- glucose_tolerance_test <= 127.50
# |   |--- age <= 28.50
# |   |   |--- bmi <= 49.05
# |   |   |   |--- bmi <= 30.95
# |   |   |   |   |--- times_pregnant <= 7.50
# |   |   |   |   |   |--- pedigree_function <= 0.67
# |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- pedigree_function >  0.67
# |   |   |   |   |   |   |--- pedigree_function <= 0.70
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- pedigree_function >  0.70
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |--- times_pregnant >  7.50
# |   |   |   |   |   |--- class: 1
# |   |   |   |--- bmi >  30.95
# |   |   |   |   |--- pedigree_function <= 0.50
# |   |   |   |   |   |--- bmi <= 31.10
# |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- bmi >  31.10
# |   |   |   |   |   |   |--- skin_thickness <= 8.00
# |   |   |   |   |   |   |   |--- glucose_tolerance_test <= 109.50
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- glucose_tolerance_test >  109.50
# |   |   |   |   |   |   |   |   |--- bmi <= 32.45
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- bmi >  32.45
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- skin_thickness >  8.00
# |   |   |   |   |   |   |   |--- bmi <= 31.80
# |   |   |   |   |   |   |   |   |--- times_pregnant <= 2.50
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- times_pregnant >  2.50
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- bmi >  31.80
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |--- pedigree_function >  0.50
# |   |   |   |   |   |--- bmi <= 38.75
# |   |   |   |   |   |   |--- bmi <= 37.60
# |   |   |   |   |   |   |   |--- glucose_tolerance_test <= 98.50
# |   |   |   |   |   |   |   |   |--- pedigree_function <= 1.27
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- pedigree_function >  1.27
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- glucose_tolerance_test >  98.50
# |   |   |   |   |   |   |   |   |--- blood_pressure <= 69.00
# |   |   |   |   |   |   |   |   |   |--- glucose_tolerance_test <= 116.00
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- glucose_tolerance_test >  116.00
# |   |   |   |   |   |   |   |   |   |   |--- glucose_tolerance_test <= 124.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |   |--- glucose_tolerance_test >  124.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- blood_pressure >  69.00
# |   |   |   |   |   |   |   |   |   |--- bmi <= 32.35
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- bmi >  32.35
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- bmi >  37.60
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- bmi >  38.75
# |   |   |   |   |   |   |--- class: 0
# |   |   |--- bmi >  49.05
# |   |   |   |--- class: 1
# |   |--- age >  28.50
# |   |   |--- bmi <= 26.35
# |   |   |   |--- class: 0
# |   |   |--- bmi >  26.35
# |   |   |   |--- glucose_tolerance_test <= 101.50
# |   |   |   |   |--- insulin <= 205.50
# |   |   |   |   |   |--- glucose_tolerance_test <= 28.50
# |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- glucose_tolerance_test >  28.50
# |   |   |   |   |   |   |--- pedigree_function <= 1.12
# |   |   |   |   |   |   |   |--- glucose_tolerance_test <= 94.50
# |   |   |   |   |   |   |   |   |--- age <= 52.00
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- age >  52.00
# |   |   |   |   |   |   |   |   |   |--- skin_thickness <= 16.00
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- skin_thickness >  16.00
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- glucose_tolerance_test >  94.50
# |   |   |   |   |   |   |   |   |--- skin_thickness <= 32.50
# |   |   |   |   |   |   |   |   |   |--- glucose_tolerance_test <= 98.00
# |   |   |   |   |   |   |   |   |   |   |--- pedigree_function <= 0.43
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |   |--- pedigree_function >  0.43
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |--- glucose_tolerance_test >  98.00
# |   |   |   |   |   |   |   |   |   |   |--- blood_pressure <= 30.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |   |--- blood_pressure >  30.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- skin_thickness >  32.50
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- pedigree_function >  1.12
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- insulin >  205.50
# |   |   |   |   |   |--- class: 1
# |   |   |   |--- glucose_tolerance_test >  101.50
# |   |   |   |   |--- pedigree_function <= 0.56
# |   |   |   |   |   |--- pedigree_function <= 0.20
# |   |   |   |   |   |   |--- age <= 34.50
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- age >  34.50
# |   |   |   |   |   |   |   |--- glucose_tolerance_test <= 108.50
# |   |   |   |   |   |   |   |   |--- age <= 36.50
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- age >  36.50
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- glucose_tolerance_test >  108.50
# |   |   |   |   |   |   |   |   |--- times_pregnant <= 10.50
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- times_pregnant >  10.50
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- pedigree_function >  0.20
# |   |   |   |   |   |   |--- times_pregnant <= 1.50
# |   |   |   |   |   |   |   |--- blood_pressure <= 92.00
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- blood_pressure >  92.00
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- times_pregnant >  1.50
# |   |   |   |   |   |   |   |--- pedigree_function <= 0.39
# |   |   |   |   |   |   |   |   |--- bmi <= 34.45
# |   |   |   |   |   |   |   |   |   |--- age <= 55.00
# |   |   |   |   |   |   |   |   |   |   |--- bmi <= 31.15
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |   |--- bmi >  31.15
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |   |   |--- age >  55.00
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- bmi >  34.45
# |   |   |   |   |   |   |   |   |   |--- blood_pressure <= 68.00
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- blood_pressure >  68.00
# |   |   |   |   |   |   |   |   |   |   |--- blood_pressure <= 94.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |   |--- blood_pressure >  94.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- pedigree_function >  0.39
# |   |   |   |   |   |   |   |   |--- times_pregnant <= 11.50
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- times_pregnant >  11.50
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- pedigree_function >  0.56
# |   |   |   |   |   |--- times_pregnant <= 3.00
# |   |   |   |   |   |   |--- age <= 31.00
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- age >  31.00
# |   |   |   |   |   |   |   |--- blood_pressure <= 84.00
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- blood_pressure >  84.00
# |   |   |   |   |   |   |   |   |--- skin_thickness <= 15.00
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- skin_thickness >  15.00
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- times_pregnant >  3.00
# |   |   |   |   |   |   |--- age <= 32.00
# |   |   |   |   |   |   |   |--- bmi <= 32.35
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- bmi >  32.35
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- age >  32.00
# |   |   |   |   |   |   |   |--- class: 1
# |--- glucose_tolerance_test >  127.50
# |   |--- bmi <= 29.95
# |   |   |--- glucose_tolerance_test <= 151.50
# |   |   |   |--- blood_pressure <= 23.00
# |   |   |   |   |--- class: 1
# |   |   |   |--- blood_pressure >  23.00
# |   |   |   |   |--- age <= 35.00
# |   |   |   |   |   |--- skin_thickness <= 28.00
# |   |   |   |   |   |   |--- age <= 32.50
# |   |   |   |   |   |   |   |--- skin_thickness <= 6.00
# |   |   |   |   |   |   |   |   |--- blood_pressure <= 55.00
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- blood_pressure >  55.00
# |   |   |   |   |   |   |   |   |   |--- pedigree_function <= 0.49
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- pedigree_function >  0.49
# |   |   |   |   |   |   |   |   |   |   |--- bmi <= 29.30
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |   |--- bmi >  29.30
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- skin_thickness >  6.00
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- age >  32.50
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- skin_thickness >  28.00
# |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- age >  35.00
# |   |   |   |   |   |--- class: 0
# |   |   |--- glucose_tolerance_test >  151.50
# |   |   |   |--- age <= 62.00
# |   |   |   |   |--- blood_pressure <= 87.00
# |   |   |   |   |   |--- glucose_tolerance_test <= 154.50
# |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- glucose_tolerance_test >  154.50
# |   |   |   |   |   |   |--- glucose_tolerance_test <= 160.00
# |   |   |   |   |   |   |   |--- glucose_tolerance_test <= 157.50
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- glucose_tolerance_test >  157.50
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- glucose_tolerance_test >  160.00
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- blood_pressure >  87.00
# |   |   |   |   |   |--- age <= 40.00
# |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- age >  40.00
# |   |   |   |   |   |   |--- class: 1
# |   |   |   |--- age >  62.00
# |   |   |   |   |--- class: 0
# |   |--- bmi >  29.95
# |   |   |--- glucose_tolerance_test <= 157.50
# |   |   |   |--- bmi <= 42.85
# |   |   |   |   |--- age <= 42.50
# |   |   |   |   |   |--- blood_pressure <= 61.00
# |   |   |   |   |   |   |--- age <= 35.00
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- age >  35.00
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- blood_pressure >  61.00
# |   |   |   |   |   |   |--- insulin <= 192.00
# |   |   |   |   |   |   |   |--- pedigree_function <= 0.32
# |   |   |   |   |   |   |   |   |--- blood_pressure <= 67.00
# |   |   |   |   |   |   |   |   |   |--- glucose_tolerance_test <= 145.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- glucose_tolerance_test >  145.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- blood_pressure >  67.00
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- pedigree_function >  0.32
# |   |   |   |   |   |   |   |   |--- glucose_tolerance_test <= 152.50
# |   |   |   |   |   |   |   |   |   |--- insulin <= 125.00
# |   |   |   |   |   |   |   |   |   |   |--- blood_pressure <= 86.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |   |--- blood_pressure >  86.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- insulin >  125.00
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- glucose_tolerance_test >  152.50
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- insulin >  192.00
# |   |   |   |   |   |   |   |--- times_pregnant <= 9.50
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- times_pregnant >  9.50
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- age >  42.50
# |   |   |   |   |   |--- pedigree_function <= 1.39
# |   |   |   |   |   |   |--- glucose_tolerance_test <= 128.50
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- glucose_tolerance_test >  128.50
# |   |   |   |   |   |   |   |--- bmi <= 31.05
# |   |   |   |   |   |   |   |   |--- blood_pressure <= 84.00
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- blood_pressure >  84.00
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- bmi >  31.05
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- pedigree_function >  1.39
# |   |   |   |   |   |   |--- class: 0
# |   |   |   |--- bmi >  42.85
# |   |   |   |   |--- age <= 46.50
# |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- age >  46.50
# |   |   |   |   |   |--- class: 0
# |   |   |--- glucose_tolerance_test >  157.50
# |   |   |   |--- insulin <= 629.50
# |   |   |   |   |--- pedigree_function <= 0.34
# |   |   |   |   |   |--- skin_thickness <= 6.50
# |   |   |   |   |   |   |--- times_pregnant <= 9.50
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- times_pregnant >  9.50
# |   |   |   |   |   |   |   |--- age <= 40.50
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- age >  40.50
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- skin_thickness >  6.50
# |   |   |   |   |   |   |--- skin_thickness <= 16.50
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- skin_thickness >  16.50
# |   |   |   |   |   |   |   |--- insulin <= 86.00
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- insulin >  86.00
# |   |   |   |   |   |   |   |   |--- bmi <= 45.60
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- bmi >  45.60
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |--- pedigree_function >  0.34
# |   |   |   |   |   |--- age <= 44.00
# |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- age >  44.00
# |   |   |   |   |   |   |--- pedigree_function <= 1.16
# |   |   |   |   |   |   |   |--- age <= 50.00
# |   |   |   |   |   |   |   |   |--- blood_pressure <= 70.00
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- blood_pressure >  70.00
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- age >  50.00
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- pedigree_function >  1.16
# |   |   |   |   |   |   |   |--- times_pregnant <= 7.50
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- times_pregnant >  7.50
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |--- insulin >  629.50
# |   |   |   |   |--- bmi <= 33.40
# |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- bmi >  33.40
# |   |   |   |   |   |--- class: 0

# %%
plt.figure(figsize=(20, 10))
clf = tree.DecisionTreeClassifier().fit(x,y)
plot_tree(clf, filled=True, feature_names=names[0:8],max_depth=4,fontsize=5)
plt.show()
